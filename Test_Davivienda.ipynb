# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
from sklearn.metrics import mean_absolute_error

import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Test_Davivienda/Base_Classification_test.csv'

# %%
df = pd.read_csv(path, sep=',')

# %%
df
# Out:
#          ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0      5524        1957  Graduation  ...             3         11         1
# 1      2174        1954  Graduation  ...             3         11         0
# 2      4141        1965  Graduation  ...             3         11         0
# 3      6182        1984  Graduation  ...             3         11         0
# 4      5324        1981         PhD  ...             3         11         0
# ...     ...         ...         ...  ...           ...        ...       ...
# 2235  10870        1967  Graduation  ...             3         11         0
# 2236   4001        1946         PhD  ...             3         11         0
# 2237   7270        1981  Graduation  ...             3         11         0
# 2238   8235        1956      Master  ...             3         11         0
# 2239   9405        1954         PhD  ...             3         11         1
#
# [2240 rows x 29 columns]

# %%
x= sub('Hello', 0, 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-73bf4b1fdd33> in <module>()
# ----> 1 x= sub('Hello', 0, 1)
#
# NameError: name 'sub' is not defined

# %%
all([1,'b', 1])
# Out:
# True

# %%
400000*0.08
# Out:
# 32000.0

# %%
12/32
# Out:
# 0.375

# %%
a = 65000000*.55
a
# Out:
# 35750000.0

# %%
s= 4150000-a
s
# Out:
# -31600000.0

# %%
100*.09+100*.09*
# Out:
# 9.0

# %%
100

# %%
0.15*(500+700+700+900)
# Out:
# 420.0

# %%
complejidad computacional del while
